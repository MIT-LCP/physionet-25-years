# %% [markdown]
# # Searching for keywords in journals
#
# This notebook looks at how PhysioNet resources are being used in journals.

# %% [markdown]
# ## Setup

# %%
import os
import pandas as pd
from twentyfiveyears.models import (PublicationVenue,
                                    Publication,
                                    VenueCollection)

# %% [markdown]
# ## Create list of journals
#
# We'll first create the following objects:
#
# - List of conferences (`PublicationVenue`)
# - List of papers associated with each conference (`Publication`)
# - A collection of conferences (`VenueCollection`)

# %%
# make a list of conferences that we would like to explore
journal_list = {"applied_clinical_health": "applied_clinical_health",
                "bmc_digital_health": "bmc_digital_health",
                "gigascience": "gigascience",
                "jamia": "jamia",
                "jamia_open": "jamia_open",
                "jmir": "jmir",
                "lancet_digital_health": "lancet_digital_health",
                "nature_digital_medicine": "nature_digital_medicine",
                "nature_scientific_data": "nature_scientific_data",
                "plos_digital_health": "plos_digital_health",
               }

# %%
# initialize collection of conferences
journals = VenueCollection()

# path to papers
base_path = os.path.join("..", "data", "papers", "2023")

# create the collection of conferences
for shortname, title in journal_list.items():
    path = os.path.join(base_path, shortname)
    journal = PublicationVenue(title=title,
                               shortname=shortname,
                               year=2023,
                               path=path)
    journals.add(journal)

# %% [markdown]
# ## Add publications to journals
#
# We can now associate a list of publications with each journal.

# %%
# for each journal
# add the publications in the journal folder
# unfortunately we aren't able to populate the title, authors, etc.
for journal in journals:
    for file in os.listdir(journal.path):
        if file.endswith('.pdf'):
            paper = Publication(path=journal.path,
                                filename=file)
            journal.add_publication(paper)

# %%
print(f"Number of journals: {len(journals)}")
# Out:
# Number of journals: 10

# %% [markdown]
# ## Find keywords in publications¶
#
# Now search for our keywords of interest.

# %%
# define a set of keywords to search.
keywords = ["PhysioNet",
            "physionet",
            "Physionet",
            "MIMIC",
            "MIMIC-III",
            "MIMIC-IV"
            "MIMIC-ED",
            "MIMIC-CXR",
            "MIMIC-IV-ED",
            "MIMIC-IV-CXR",
            "MIMIC-IV-ECG",
            "MIMIC-IV-ECHO",
            "wfdb",
            "WFDB",
            "10.13026",
            "eICU-CRD",
            "MIT-BIH",
            "WFDB"
           ]

# %%
# search across venues
journals.search_keywords_across_venues(keywords)
# Out:
# Error reading PDF file: Failed to open file '../data/papers/2023/jamia/ocad126.pdf'.
# Error reading PDF file: Failed to open file '../data/papers/2023/jamia/ocad149.pdf'.
# Error reading PDF file: Failed to open file '../data/papers/2023/nature_scientific_data/s41597-023-02458-8.pdf'.

# %% [markdown]
# ## Summarize findings
#
# Summarize the findings of the keyword search.

# %%
for journal in journals:
    journal.summarize()
# Out:
# applied_clinical_health (2023):
# - Total publications: 12
# - Publications containing keyword: 0
# - Proportion of publications containing keyword: 0.00%
#
# bmc_digital_health (2023):
# - Total publications: 50
# - Publications containing keyword: 0
# - Proportion of publications containing keyword: 0.00%
#
# gigascience (2023):
# - Total publications: 108
# - Publications containing keyword: 1
# - Proportion of publications containing keyword: 0.93%
#
# jamia (2023):
# - Total publications: 248
# - Publications containing keyword: 25
# - Proportion of publications containing keyword: 10.08%
#
# jamia_open (2023):
# - Total publications: 117
# - Publications containing keyword: 7
# - Proportion of publications containing keyword: 5.98%
#
# jmir (2023):
# - Total publications: 1019
# - Publications containing keyword: 7
# - Proportion of publications containing keyword: 0.69%
#
# lancet_digital_health (2023):
# - Total publications: 56
# - Publications containing keyword: 2
# - Proportion of publications containing keyword: 3.57%
#
# nature_digital_medicine (2023):
# - Total publications: 239
# - Publications containing keyword: 24
# - Proportion of publications containing keyword: 10.04%
#
# nature_scientific_data (2023):
# - Total publications: 905
# - Publications containing keyword: 19
# - Proportion of publications containing keyword: 2.10%
#
# plos_digital_health (2023):
# - Total publications: 199
# - Publications containing keyword: 7
# - Proportion of publications containing keyword: 3.52%
